# %% [markdown]
# # Introduction to NetworkX
# ---
#
# We will use the Python library [NetworkX](https://networkx.github.io/index.html). It is well documented and several [examples](https://networkx.github.io/documentation/networkx-2.0/auto_examples/index.html) are available.
#
# It is not the only Python library available for network analysis. Another very good one is [graph-tool](https://graph-tool.skewed.de/).
# Also the [SNAP library](http://snap.stanford.edu/data/index.html) provides an excellent tool to analyze very large networks.

# %% [markdown]
# ## NetworkX preliminaries

# %%
import networkx as nx

from operator import itemgetter

import math

# %% [markdown]
# We import the plotting library seaborn which integrates very well with matplotlib.
# More documentation is available here: https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import watermark
# %load_ext watermark

# %%
# %watermark -n -v -m -iv
# Out:
# Python implementation: CPython
# Python version       : 3.9.16
# IPython version      : 8.3.0
#
# Compiler    : Clang 14.0.0 (clang-1400.0.29.202)
# OS          : Darwin
# Release     : 22.3.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 10
# Architecture: 64bit
#
# numpy     : 1.23.5
# networkx  : 2.8
# logging   : 0.5.1.2
# re        : 2.2.1
# sys       : 3.9.16 (main, Dec  7 2022, 10:06:04)
# [Clang 14.0.0 (clang-1400.0.29.202)]
# matplotlib: 3.5.2
# seaborn   : 0.11.2
# watermark : 2.3.1
# json      : 2.0.9

# %% [markdown]
# ---
# Generate an empty UNDIRECTED graph with NetworkX

# %%
G = nx.Graph()

# %% [markdown]
# Add nodes from a list of names

# %%
G.add_nodes_from(['Luca','Andrea','Sara','Carlo','Veronica'])

# %%
list(G.nodes())
# Out:
# ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica']

# %% [markdown]
# Add another node

# %%
G.add_node('Giovanni')

print("The nodes of G are: ", G.nodes())
# Out:
# The nodes of G are:  ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica', 'Giovanni']

# %% [markdown]
# So far we have nodes in the networks but no edges.
# Let's add edges from a list of tuples.

# %%
G.add_edges_from([('Luca','Sara'),('Andrea','Luca'),
('Carlo','Veronica'),('Sara','Veronica'),('Giovanni','Andrea')])

# %%
G.edges()
# Out:
# EdgeView([('Luca', 'Sara'), ('Luca', 'Andrea'), ('Andrea', 'Giovanni'), ('Sara', 'Veronica'), ('Carlo', 'Veronica')])

# %% [markdown]
# We add another edge and 'Lucia' is a new node.

# %%
G.add_edge('Veronica','Lucia')

print("The nodes of G are : ", G.nodes())
print('---')
print("The links of G are : ", G.edges())
# Out:
# The nodes of G are :  ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica', 'Giovanni', 'Lucia']
# ---
# The links of G are :  [('Luca', 'Sara'), ('Luca', 'Andrea'), ('Andrea', 'Giovanni'), ('Sara', 'Veronica'), ('Carlo', 'Veronica'), ('Veronica', 'Lucia')]

# %% [markdown]
# We want to add the property 'age' to each node. By default, each node is assigned to an empty dictionary to store metadata.

# %%
G.nodes['Lucia']
# Out:
# {}

# %%
for n in G.nodes():
    if n[0]=='L':
        G.nodes[n]['age']=24
    else:
        G.nodes[n]['age']=28

#show the nodes with their age
print(G.nodes(data=True))
# Out:
# [('Luca', {'age': 24}), ('Andrea', {'age': 28}), ('Sara', {'age': 28}), ('Carlo', {'age': 28}), ('Veronica', {'age': 28}), ('Giovanni', {'age': 28}), ('Lucia', {'age': 24})]

# %%
d = nx.get_node_attributes(G, 'age')

# %% [markdown]
# How to remove a node?

# %%
G.remove_node('Luca')
print(G.nodes(data=True))
print('---')
print(G.edges())
# Out:
# [('Andrea', {'age': 28}), ('Sara', {'age': 28}), ('Carlo', {'age': 28}), ('Veronica', {'age': 28}), ('Giovanni', {'age': 28}), ('Lucia', {'age': 24})]
# ---
# [('Andrea', 'Giovanni'), ('Sara', 'Veronica'), ('Carlo', 'Veronica'), ('Veronica', 'Lucia')]

# %% [markdown]
# If we remove an edge, we do not remove the nodes!

# %%
G.remove_edge('Giovanni', 'Andrea')

# %%
print(G.nodes())
# Out:
# ['Andrea', 'Sara', 'Carlo', 'Veronica', 'Giovanni', 'Lucia']

# %% [markdown]
# Degree is easily accessible

# %%
G.degree('Veronica')
# Out:
# 3

# %%
G.degree()
# Out:
# DegreeView({'Andrea': 0, 'Sara': 1, 'Carlo': 1, 'Veronica': 3, 'Giovanni': 0, 'Lucia': 1})

# %%
for i in G.degree():
    print(i[0], G.degree()[i[0]])
# Out:
# Andrea 0
# Sara 1
# Carlo 1
# Veronica 3
# Giovanni 0
# Lucia 1

# %% [markdown]
# ### Analyze the citHepTh network with NetworkX
# ---
# We analyze the citation dataset (citHepTh) available on the [Stanford Large Network Data Colletion](http://snap.stanford.edu/data/index.html).
#
# Keep in mind that the network is directed!

# %%
filepath = "./../datasets/cit-HepTh.txt"

# %%
H = nx.DiGraph()

# %%
# !more ./../datasets/cit-HepTh.txt
# Out:
# # Directed graph (each unordered pair of nodes is saved once): Cit-HepTh.txt
# # Paper citation network of Arxiv High Energy Physics Theory category
# # Nodes: 27770 Edges: 352807
# # FromNodeId    ToNodeId
# 1001    9304045
# 1001    9308122
# 1001    9309097
# 1001    9311042
# 1001    9401139
# 1001    9404151
# 1001    9407087
# 1001    9408099
# 1001    9501030
# 1001    9503124
# 1001    9504090
# 1001    9504145
# 1001    9505025
# 1001    9505054
# 1001    9505105
# 1001    9505162
# 1001    9506048
# 1001    9506112
# 1001    9506144
# >atasets/cit-HepTh.txt

# %%
fh = open(filepath, "r")

# reading all the file lines
for line in fh.readlines():
    # remove "\n" characters (.strip()) and split the line at blank spaces (split.())
    s = line.strip().split()
    if s[0] != "#":
        # the first lines are comments
        origin = int(s[0])
        dest = int(s[1])

        H.add_edge(origin, dest)

# chiudo il file
fh.close()

# %%
print("The network has", len(H), "nodes")
# Out:
# The network has 27770 nodes

# %%
print("The network has", len(H.edges()), "edges")
# Out:
# The network has 352807 edges

# %% [markdown]
# #### We want to count how many nodes have a given degree-in
# The Counter module is a dictionary subclass that allows quick item counting.

 1, 383: 1, 217: 1, 225: 1, 438: 1, 701: 1, 1199: 1, 456: 1, 235: 1, 297: 1, 214: 1, 2414: 1, 1144: 1, 168: 1, 1032: 1, 135: 1, 211: 1, 1641: 1, 1775: 1, 248: 1, 315: 1, 295: 1, 475: 1, 308: 1, 130: 1, 807: 1, 213: 1, 251: 1, 187: 1, 244: 1, 427: 1, 184: 1, 181: 1, 265: 1, 347: 1, 247: 1, 264: 1, 165: 1, 180: 1, 183: 1, 224: 1, 340: 1, 341: 1, 198: 1, 147: 1, 331: 1, 182: 1, 212: 1})

# %%
x=[]
y=[]

for i in sorted(degin_distri):   
    x.append(i)
    y.append(degin_distri[i]/len(H))

plt.figure(figsize=(10,7))    
plt.plot(x,y)

plt.xlabel('$k_{in}$', fontsize=18)
plt.ylabel('$P(k_{in})$', fontsize=18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.yscale('log')
plt.xscale('log')
plt.axis([1,10000,0.00001,1.0])
# Out:
# (1.0, 10000.0, 1e-05, 1.0)

# %% [markdown]
# Let's plot the degree out distribution

# %%
outdeg = dict(H.out_degree()).values()
degout_distri = Counter(outdeg)

# %%
x=[]
y=[]
for i in sorted(degout_distri):   
    x.append(i)
    y.append(float(degout_distri[i])/len(H))

plt.figure(figsize=(10,7))    
plt.plot(np.array(x),np.array(y))

plt.xlabel('$k_{out}$', fontsize=18)
plt.ylabel('$P(k_{out})$', fontsize=18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.yscale('log')
plt.xscale('log')
plt.axis([1,10000,0.00001,1.0])
# Out:
# (1.0, 10000.0, 1e-05, 1.0)

# %% [markdown]
# #### Export to gml (be careful this is a large network!)

# %% [markdown]
# The file in gml format can be visualized using the software tool Gephi (http://gephi.org).

# %%
#nx.write_gml(H,'./../network_data/citHepTh.gml')

# %% [markdown]
# ## Visualizing a network with NetworkX

# %% [markdown]
# NetworkX combined with matplotlib can be used to visualize complex networks.
#
# It provides a good range of functionalities to obtain some basic and more refined visualization. More details are available in the [documentation](https://networkx.github.io/documentation/stable/reference/drawing.html).

# %% [markdown]
# Notice, as stated in the documentation
# >NetworkX provides basic functionality for visualizing graphs, but its main goal is to enable graph analysis rather than perform graph visualization.
# >In the future, graph visualization functionality may be removed from NetworkX or only available as an add-on package.

# %% [markdown]
# We generate a random Erdos-Rényi network and visualize it.

# %%
N=100
prob=0.08

# %%
ER=nx.erdos_renyi_graph(N, prob)

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(ER)
plt.axis('off')
# Out:
# (-0.9351426914967018,
#  1.183882337201044,
#  -1.0935721905639388,
#  0.8757230191976545)

# %%
plt.figure(figsize=(10,10))
nx.draw_circular(ER)

# %%
plt.figure(figsize=(10,10))
nx.draw_random(ER)

# %%
plt.figure(figsize=(10,10))
nx.draw_spring(ER)

# %%
pos=nx.kamada_kawai_layout(ER)
pos
# Out:
# {0: array([0.88467194, 0.17563866]),
#  1: array([ 0.04635149, -0.05913314]),
#  2: array([ 0.59503501, -0.29771544]),
#  3: array([-0.61318064,  0.116437  ]),
#  4: array([-0.10865643,  0.35234718]),
#  5: array([ 0.82409087, -0.1122654 ]),
#  6: array([-0.03171751,  0.09584684]),
#  7: array([0.73504373, 0.55719777]),
#  8: array([0.5812074 , 0.46539501]),
#  9: array([-0.29227725, -0.02958421]),
#  10: array([ 0.07576971, -0.13580141]),
#  11: array([ 0.55842505, -0.40467387]),
#  12: array([-0.01199059, -0.49289709]),
#  13: array([-0.50600017,  0.22697358]),
#  14: array([ 0.52722566, -0.48316976]),
#  15: array([-0.0533626 ,  0.21244145]),
#  16: array([-0.2361819 ,  0.55619914]),
#  17: array([0.56577577, 0.30486143]),
#  18: array([ 0.35131922, -0.4657357 ]),
#  19: array([0.27918778, 0.75265761]),
#  20: array([0.34202874, 0.61328609]),
#  21: array([-0.0870253,  0.5748628]),
#  22: array([-0.53631635, -0.11469509]),
#  23: array([0.1765199 , 0.42038956]),
#  24: array([-0.18196319, -0.29135644]),
#  25: array([0.59220776, 0.17490945]),
#  26: array([-0.83382937,  0.3989801 ]),
#  27: array([-0.14375842,  0.66107059]),
#  28: array([0.72338434, 0.01416547]),
#  29: array([ 0.56460384, -0.21466319]),
#  30: array([-0.31162295, -0.18682108]),
#  31: array([ 0.41904985, -0.37229115]),
#  32: array([-0.43447485, -0.47268374]),
#  33: array([-0.03933683,  0.655795  ]),
#  34: array([-0.63478726,  0.27679863]),
#  35: array([ 0.74497973, -0.48333362]),
#  36: array([ 0.27416142, -0.34440759]),
#  37: array([-0.34489593,  0.61688363]),
#  38: array([-0.62977797, -0.39467465]),
#  39: array([-0.51299479, -0.66069407]),
#  40: array([0.14738978, 0.00656907]),
#  41: array([ 0.4474631 , -0.26224893]),
#  42: array([-0.60965181,  0.63983616]),
#  43: array([ 0.17753825, -0.44140196]),
#  44: array([-0.10245904, -0.80973758]),
#  45: array([0.32152343, 0.10568204]),
#  46: array([-0.9064433 ,  0.04332095]),
#  47: array([-0.53384684, -0.40380761]),
#  48: array([0.32865279, 0.36512869]),
#  49: array([-0.37712241, -0.14501759]),
#  50: array([0.18519439, 0.22168149]),
#  51: array([-0.44199049,  0.01445957]),
#  52: array([ 0.12619519, -0.66450675]),
#  53: array([ 0.08984984, -0.32798994]),
#  54: array([-0.37294232,  0.50613952]),
#  55: array([0.16526953, 0.11472309]),
#  56: array([-0.25469939,  0.32188451]),
#  57: array([-0.83344091, -0.05625437]),
#  58: array([0.0416125 , 0.79687279]),
#  59: array([0.56247632, 0.03896258]),
#  60: array([0.07773614, 0.65448387]),
#  61: array([-0.18825711, -0.5865213 ]),
#  62: array([0.23141231, 0.56217716]),
#  63: array([-0.11740122,  0.03844831]),
#  64: array([-0.23139374,  0.06421046]),
#  65: array([ 0.67337906, -0.09756645]),
#  66: array([ 0.28933024, -0.11530476]),
#  67: array([ 0.36159183, -0.74069838]),
#  68: array([-0.66405693, -0.12770751]),
#  69: array([-0.53547502,  0.13948724]),
#  70: array([0.49111966, 0.0857338 ]),
#  71: array([ 0.48667237, -0.03797061]),
#  72: array([0.46751068, 0.29217535]),
#  73: array([-0.58052111, -0.56974256]),
#  74: array([-0.5739673 , -0.32209612]),
#  75: array([-0.52665193,  0.05819555]),
#  76: array([-0.29030909,  0.1845937 ]),
#  77: array([ 0.24879702, -0.59921036]),
#  78: array([-0.33589857, -1.        ]),
#  79: array([-0.01239113,  0.36422342]),
#  80: array([-0.17825589,  0.53024679]),
#  81: array([0.38603221, 0.32123193]),
#  82: array([ 0.3182792 , -0.02143621]),
#  83: array([-0.48193905, -0.23316795]),
#  84: array([-0.21860735, -0.16851101]),
#  85: array([-0.30598626, -0.75477554]),
#  86: array([0.47713992, 0.76813949]),
#  87: array([ 0.07359547, -0.72586075]),
#  88: array([-0.37827404,  0.31172608]),
#  89: array([ 0.22703591, -0.24208658]),
#  90: array([0.07278143, 0.22862185]),
#  91: array([-0.3333413 , -0.64179226]),
#  92: array([0.35688498, 0.52771728]),
#  93: array([-0.11618644, -0.38816038]),
#  94: array([-0.39731144,  0.38347318]),
#  95: array([ 0.05920401, -0.43840668]),
#  96: array([0.47191445, 0.49780572]),
#  97: array([-0.12183471, -0.68987547]),
#  98: array([-0.61368893,  0.46273717]),
#  99: array([-0.04612585, -0.24537351])}

# %% [markdown]
# We can draw the network nodes only, and assign a specific location to each node.

# %%
plt.figure(figsize=(8,6))
nx.draw_networkx_nodes(ER, pos)
plt.axis('off')
# Out:
# (-0.9959990615810936,
#  0.9742277060590447,
#  -1.089843639387847,
#  0.8867164271447858)

# %%
plt.figure(figsize=(10,7))

s=nx.draw_networkx_nodes(ER,
            pos,
            node_size=100.0,
            node_color=list(dict(nx.degree(ER)).values()),
            alpha=1,
            cmap=plt.cm.BuGn
            )

nx.draw_networkx_edges(ER, pos, alpha=0.5)

#show the colorbar on the right side
cbar=plt.colorbar(s)
cbar.ax.set_ylabel('Degree', size=22)

plt.axis('off')
plt.show()

# %% [markdown]
# ## Visualizing a spatial network with NetworkX

# %% [markdown]
# We analyze the US airport network of year 2010.
# The network is available from the [network repository of Tore Opshal](https://toreopsahl.com/datasets/#usairports).
#
# Weights represent the total number of passengers who traveled on that connection in a year.
#
# Airport coordinates have been added by myself.

# %%
airport_path='./../datasets/USairport_2010.txt'

# %%
meta_path='./../datasets/USairport_2010_codes.txt'

# %%
# !cat ./../datasets/USairport_2010_codes.txt
# Out:
# 29 ABE Allentown 40.654722 -75.438333
# 30 ABI Abilene 32.409444 -99.679722
# 32 ABQ Albuquerque 35.041667 -106.606389
# 33 ABR Aberdeen 45.449722 -98.421667
# 35 ABY Albany 31.532222 -84.196111
# 38 ACK Nantucket 41.256667 -70.059722
# 39 ACT Waco 31.611389 -97.228611
# 40 ACV Eureka_Arcata 40.979167 -124.1075
# 41 ACY Atlantic_City 39.456111 -74.578056
# 52 AEX Alexandria(Intl) 31.324167 -92.546944
# 60 AGS Augusta 33.369167 -81.964444
# 63 AHN Athens 33.948333 -83.326944
# 64 AIA Alliance 42.051667 -102.806667
# 75 ALB Albany 42.745833 -73.805278
# 76 ALM Alamogordo 32.839722 -105.99
# 78 ALO Waterloo 42.556111 -92.399722
# 79 ALS Alamosa 37.436667 -105.866667
# 80 ALW Walla_Walla 46.094722 -118.291111
# 82 AMA Amarillo 35.227222 -101.721944
# 96 AOO Altoona 40.297222 -78.32
# 100 APF Naples 26.152778 -81.775278
# 101 APN Alpena 45.081667 -83.555833
# 106 ART Watertown 43.990833 -76.021389
# 108 ASE Aspen 39.224167 -106.868889
# 114 ATL Atlanta 33.640833 -84.427222
# 117 ATW Appleton 44.258889 -88.521111
# 118 ATY Watertown 44.908889 -97.154167
# 120 AUG Augusta 44.318056 -69.796667
# 123 AUS Austin 30.298056 -97.701389
# 126 AVL Asheville 35.435 -82.541111
# 127 AVP Wilkes_Barre_Scranton 41.339167 -75.725833
# 134 AZO Kalamazoo 42.236389 -85.553611
# 145 BDL Hartford_Ct_Springfield 41.9375 -72.683056
# 149 BED Bedford 42.470833 -71.29
# 154 BFD Bradford 41.802222 -78.639444
# 155 BFF Scottsbluff 41.875278 -103.601111
# 158 BFL Bakersfield 35.43 -119.052222
# 163 BGM Binghamton 42.201389 -75.969167
# 164 BGR Bangor 44.807778 -68.827778
# 167 BHB Bar_Harbor 44.448889 -68.361667
# 169 BHM Birmingham 33.563056 -86.755556
# 176 BIL Billings 45.806944 -108.542778
# 179 BIS Bismarck 46.778889 -100.7525
# 182 BJI Bemidji 47.509722 -94.934722
# 191 BKW Beckley 37.781944 -81.124167
# 194 BLF Bluefield 37.295833 -81.208056
# 196 BLI Bellingham 48.794444 -122.534722
# 204 BMI Bloomington 40.481944 -88.9275
# 206 BNA Nashville 36.126667 -86.681944
# 211 BOI Boise 43.565278 -116.225
# 215 BOS Boston 42.363611 -71.006111
# 216 BPT Beaumont_Pt_Arthur 29.950833 -94.02
# 217 BQK Brunswick 31.258889 -81.466389
# 219 BRD Brainerd 46.397222 -94.1375
# 221 BRL Burlington 40.786111 -91.123333
# 224 BRO Brownsville 25.906389 -97.425556
# 233 BTM Butte 45.951111 -112.493889
# 234 BTR Baton_Rouge 30.531667 -91.150556
# 237 BTV Burlington 44.472778 -73.153056
# 239 BUF Buffalo 42.940556 -78.7325
# 244 BWD Brownwood 31.794722 -98.956667
# 246 BWI Baltimore 39.175556 -76.671389
# 251 BZN Bozeman 45.780278 -111.159444
# 256 CAE Columbia 33.936389 -81.115833
# 258 CAK Akron_Canton 40.913889 -81.441667
# 261 CBE Cumberland 39.614444 -78.766111
# 265 CDC Cedar_City 37.7025 -113.096111
# 268 CDR Chadron 42.835 -103.097778
# 271 CEC Crescent_City 41.78 -124.235833
# 278 CEZ Cortez 37.302778 -108.627222
# 285 CGI Cape_Girardeau 37.223611 -89.571667
# 290 CHA Chattanooga 35.036389 -85.203611
# 702 HYA Hyannis 41.665833 -70.280556
# 706 HYS Hays 38.846111 -99.274167
# 709 IAD Washington_IAD_DCA 38.941667 -77.4575
# 711 IAH Houston_IAH_EFD_HOU 29.983333 -95.34
# 716 ICT Wichita 37.65 -97.432778
# 718 IDA Idaho_Falls 43.516111 -112.064722
# 719 IFP Bullhead_City 35.164444 -114.565278
# 721 IGM Kingman 35.256667 -113.94
# 727 ILM Wilmington 34.266944 -77.903889
# 729 IMT Iron_Mountain 45.815556 -88.114167
# 731 IND Indianapolis 39.728889 -86.281667
# 732 INL Intl_Falls 48.563056 -93.404167
# 738 IPL El_Centro_Imperial 32.837222 -115.574722
# 739 IPT Williamsport 41.242222 -76.920556
# 744 IRK Kirksville 40.0925 -92.543889
# 747 ISN Williston 48.176111 -103.636111
# 749 ISP Long_Island_Macarthur 40.796667 -73.100833
# 752 ITH Ithaca 42.490278 -76.458056
# 755 IWD Ironwood 46.525556 -90.131667
# 757 IYK Inyokern 35.656667 -117.829167
# 758 JAC Jackson_Hole 43.606667 -110.736944
# 759 JAN Jackson 32.309722 -90.075833
# 760 JAX Jacksonville 30.484722 -81.687778
# 761 JBR Jonesboro 35.83 -90.648333
# 769 JHW Jamestown 42.150556 -79.258056
# 771 JLN Joplin 37.149722 -94.497778
# 773 JMS Jamestown 46.93 -98.678333
# 780 JST Johnstown 40.316667 -78.834444
# 870 LAF Lafayette 40.411944 -86.933611
# 872 LAN Lansing 42.779167 -84.588333
# 874 LAR Laramie 41.313611 -105.673056
# 875 LAS Las_Vegas_LAS_VGT 36.08 -115.152222
# 876 LAW Lawton 34.569722 -98.416111
# 877 LAX Los_Angeles_LAX_ONT_SNA_BUR_LGB 34.066389 -118.124444
# 879 LBB Lubbock 33.662222 -101.822778
# 880 LBE Latrobe 40.276389 -79.402778
# 881 LBF North_Platte 41.128333 -100.696667
# 883 LBL Liberal 37.044444 -100.960556
# 888 LCH Lake_Charles 30.131111 -93.225556
# 894 LEB Lebanon 43.628056 -72.305833
# 899 LEX Lexington 38.036944 -84.605278
# 901 LFT Lafayette 30.204722 -91.9875
# 918 LIT Little_Rock 34.729167 -92.234444
# 925 LMT Klamath_Falls 42.163056 -121.735833
# 926 LNK Lincoln 40.850833 -96.758889
# 927 LNS Lancaster 40.121111 -76.299722
# 935 LPS Lopez_Island 48.482778 -122.935556
# 936 LRD Laredo 27.544722 -99.461111
# 940 LSE La_Crosse_Wi_Winona 43.877222 -91.256389
# 953 LWB Greenbrier 37.859722 -80.398611
# 956 LWS Lewiston 46.374722 -117.014444
# 957 LWT Lewistown 47.051111 -109.471111
# 959 LYH Lynchburg 37.326944 -79.201111
# 964 MAF Midland_Odessa 31.940833 -102.201389
# 971 MBL Manistee 44.273889 -86.253333
# 972 MBS Saginaw 43.531667 -84.081667
# 975 MCE Merced 37.284722 -120.512778
# 978 MCI Kansas_City 39.2975 -94.713889
# 979 MCK Mc_Cook 40.206111 -100.59
# 1442 SGU St_George 37.093056 -113.592222
# 1445 SHD Shenandoah_Valley_Airport 38.263889 -78.896667
# 1449 SHR Sheridan 44.774167 -106.977222
# 1450 SHV Shreveport 32.446944 -93.828611
# 1461 SJT San_Angelo 31.359722 -100.494444
# 1470 SLC Salt_Lake_City 40.784167 -111.966944
# 1473 SLK Saranac_Lake 44.382778 -74.206667
# 1474 SLN Salina 38.790833 -97.6525
# 1480 SMF Sacramento 38.695556 -121.589722
# 1484 SMX Santa_Maria 34.905 -120.457778
# 1493 SOP Pinehurst 35.18 -79.575833
# 1497 SPI Springfield 39.844167 -89.678889
# 1500 SPS Wichita_Falls 33.988333 -98.491944
# 1504 SRQ Sarasota_Bradenton 27.393889 -82.554167
# 1512 STC Saint_Cloud 45.545278 -94.058333
# 1517 STL St_Louis 38.747778 -90.36
# 1524 SUN Sun_Valley 43.504167 -114.308333
# 1527 SUX Sioux_City 42.401944 -96.384167
# 1529 SVC Silver_City 32.631944 -108.153889
# 1540 SWF Newburgh 41.505833 -74.097222
# 1549 SYR Syracuse 43.110556 -76.1025
# 1563 TBN Ft_Leonard_Wood 37.741389 -92.140556
# 1576 TEX Telluride 37.953889 -107.908333
# 1596 TLH Tallahassee 30.399722 -84.351944
# 1611 TOL Toledo 41.590833 -83.800833
# 1613 TPA Tampa_St_Petersburg_TPA_PIE 27.973056 -82.535278
# 1617 TRI Tri_City_Airport 36.476111 -82.406389
# 1626 TTN Trenton 40.278056 -74.8125
# 1628 TUL Tulsa 36.197778 -95.889722
# 1629 TUP Tupelo 34.258889 -88.767222
# 1630 TUS Tucson 32.116111 -110.940556
# 1631 TVC Traverse_City 44.74 -85.585833
# 1632 TVF Thief_River_Falls 48.066111 -96.185
# 1635 TWD Port_Townsend 48.05 -122.8
# 1636 TWF Twin_Falls 42.481944 -114.486667
# 1641 TXK Texarkana 33.456389 -93.989167
# 1644 TYR Tyler 32.354722 -95.398889
# 1645 TYS Knoxville 35.812222 -83.9925
# 1655 UIN Quincy 39.944167 -91.197222
# 1681 VCT Victoria 28.851111 -96.914444
# 1685 VEL Vernal 40.438889 -109.510278
# 1691 VIS Visalia 36.319444 -119.393889
# 1696 VLD Valdosta 30.782222 -83.276944
# 1700 VPS Ft_Walton_Beach 30.486667 -86.526111
# 1723 WDG Enid 36.379167 -97.790833
# 1738 WRL Worland 43.9675 -107.953056
# 1748 WYS West_Yellowstone 44.686667 -111.104722
# 1752 XNA Fayetteville 36.281944 -94.306944
# 1788 YKM Yakima 46.566944 -120.537778
# 1795 YNG Youngstown 41.256111 -80.669722
# 1821 YUM Yuma 32.654167 -114.606944

# %%
G=nx.Graph()
fh=open(airport_path,'r')
for line in fh.readlines():
    s=line.strip().split()
    G.add_edge(int(s[0]),int(s[1]))
fh.close()

# %%
len(G)
# Out:
# 405

# %% [markdown]
# Is the network fully connected?

# %%
nx.number_connected_components(G)
# Out:
# 2

# %% [markdown]
# The first connected component in the list is always the largest

# %%
c=list(nx.connected_components(G))
c[1]
# Out:
# {1182, 1347}

# %% [markdown]
# We define three dictionaries associated to the network to store additional node's features: IATA code, aiport name, geographic coordinates.

# %%
G.code={}
G.name={}
G.pos={}

# %% [markdown]
# We extract nodes features from a file

# %%
finfo=open(meta_path,'r')
for line in finfo.readlines():
    s=line.strip().split()
    node=int(s[0])
    G.code[node]=s[1]
    G.name[node]=s[2]
    G.pos[node]=(float(s[4]), float(s[3]))
finfo.close()

# %% [markdown]
# Draw the network

# %%
fig=plt.figure(figsize=(15,8))

nx.draw_networkx_nodes(G,
            pos=G.pos,
            node_size=20
            )

nx.draw_networkx_edges(G,pos=G.pos)

nx.draw_networkx_labels(G, pos=G.pos, labels=G.code)

plt.axis('off')
# Out:
# (-130.1402125, -62.147287500000004, 22.01047276, 51.339527239999995)

# %% [markdown]
# We would like to draw the edges but there are too many of them.

# %%
len(G.edges())
# Out:
# 8251

# %% [markdown]
# We select only the strongest connections as a subgraph of G by setting a threshold on the annual passengers volume.

# %%
weight_threshold=300000

# %%
H=nx.Graph()

H.pos={}
H.code={}
H.name={}

fh=open(airport_path,'r')
for line in fh.readlines():
    s=line.strip().split()
    node1=int(s[0])
    node2=int(s[1])
    
    weight=int(s[2])
    
    if weight>weight_threshold:
        H.add_edge(node1,node2)
        
        H.pos[node1]=G.pos[node1]
        H.pos[node2]=G.pos[node2]
        
        H.code[node1]=G.code[node1]
        H.code[node2]=G.code[node2]
        
        H.name[node1]=G.name[node1]
        H.name[node2]=G.name[node2]
        
fh.close()

# %%
len(H.edges())
# Out:
# 205

# %% [markdown]
# We draw the network and color code the nodes by their degree.

# %%
fig=plt.figure(figsize=(15,8))

s=nx.draw_networkx_nodes(G,
            pos=G.pos,
            node_color=[math.log(G.degree(v), 10) for v in G],
            node_size=30,
            cmap=plt.cm.YlOrRd
            )

nx.draw_networkx_edges(H,
            pos=G.pos,
            alpha=0.5
            )

nx.draw_networkx_labels(H,
            pos=H.pos,
            labels=H.code,
            )

cbar=plt.colorbar(s)
cbar.ax.set_ylabel('$log(k)$', size=22)

plt.axis('off')
# Out:
# (-128.0307916725, -65.1911527775, 23.3436116, 50.0063884)

# %% [markdown]
# What is the node with the largest degree?

# %%
max(dict(G.degree()).items(), key=itemgetter(1))
# Out:
# (389, 192)

# %%
G.name[389]
# Out:
# 'Denver'

# %% [markdown]
# ## Data visualization with NetworkX
#
# The easy interface of NetworkX and matplotlib to draw georeferenced data can be used to visualize all type of data points with geo-coordinates.
#
# A nice example comes from the electoral results of the municipality of Turin available at [the Open Data repository AperTO](http://aperto.comune.torino.it/?q=taxonomy/term/111).

# %% [markdown]
# Electoral data can be geo-referenced through the [dataset containing every street number of the city with its coordinates](http://aperto.comune.torino.it/?q=node/504).

# %% [markdown]
# Based on this idea, we created a Web-interface to explore electoral data of the city of Torino: [Il colore di Torino](http://datainterfaces.org/projects/ilcoloreditorino/)
